# %%
## Calculate a combinatorial from article Levinthals Paradox of The Interactome

import matplotlib as mpl
import numpy as np
import latex
import math
import matplotlib.pyplot as plt
from math import factorial
import sympy as sp
from sympy import init_printing
init_printing() 
from sympy import Sum, symbols, Indexed, lambdify, Integral, Limit, Rational
from sympy.abc import i, k, m, n, x, y
from sympy import Sum, factorial, oo, IndexedBase, Function
#from scipy.special import factorial

# %% [markdown]
# $\color{blue}{\rule{20 cm}{0.1 cm}}$

# %% [markdown]
# ## Case 1

# %% [markdown]
# The first pair can be selected in

# %%
Ca = (n*(n-1))/2
display(Ca)
# Out:
# n⋅(n - 1)
# ─────────
#     2

# %% [markdown]
# The second pair can be selected

# %%
Cb = ((n-2)*(n-3))/2
display(Cb)
# Out:
# (n - 3)⋅(n - 2)
# ───────────────
#        2

# %% [markdown]
# different ways, and so on to the last one (which is either a solitary protein or the complex of the last two proteins), which can be selected

# %% [markdown]
# $ \dfrac{2 \times 1}{2}  $

# %% [markdown]
# different ways, and so on to the last one (which is either a solitary protein or the complex of the last two proteins), which can be selected

# %%
Cc = sp.factorial(n)/(2**(n/2))
display(Cc)
# Out:
#  -n
#  ───
#   2
# 2   ⋅n!

# %% [markdown]
# However, this way we distinguish all interactomes that correspond to the same pattern of pairs but have them in different orders (e.g., in the case of four protines A through D, we consider the intercatome A-B + C-D different from C-D+A-B). Thus, we have to divide the number obtained by the number of the possible order of $ \dfrac{n}{2}  $ pairs, i.e.,

# %%
Cd = (sp.factorial(n/2))
display(Cd)
# Out:
# ⎛n⎞
# ⎜─⎟!
# ⎝2⎠

# %% [markdown]
# Thus, the total number of the possible realizations of the interactome is:

# %%
Cd = (sp.factorial(n))/((2**(n/2))*(sp.factorial(n/2)))
display(Cd)
#Ce = 
#display(Ce)
# Out:
#  -n
#  ───
#   2
# 2   ⋅n!
# ───────
#   ⎛n⎞
#   ⎜─⎟!
#   ⎝2⎠

# %% [markdown]
# If $\text{n} = 4500$, then:

# %% [markdown]
# $n! = \sum \limits _{k=1} ^{4500} log(k) = 10^{144487.357} = 10^{0.357} \times 10^{144487} \approx 2 \times 10^{144487}$

# %% [markdown]
# $\frac{n}{2}! = 10^{6567.323278746464} = 10^{0.323} \times 10^{6567} \approx 2 \times 10^{144487}$

# %% [markdown]
# Since by the logarithm simplication of a factorial, we have calculated:

# %% [markdown]
# $log(n!) = \sum \limits _{k=1} ^{4500} log(k) = 14487.356847657962 $

# %%
n = 4500 

nf = 0
for i in range(1, n+1):
    #print(np.log10(i))
    nf += np.log10(i)
display(nf)
# Out:
# 14487.356847657962

# %% [markdown]
# $log(\frac{n}{2}!) = \sum \limits _{k=1} ^{2250} log(k) = 6567.323278746464 $

# %%
n = 4500

nh = 0
for i in range(1, math.floor(n/2)+1):
    #print(np.log10(i))
    nh += np.log10(i)
display(nh)
# Out:
# 6567.323278746464

# %%
n = 4500
#Ce = sp.factorial(2030/7)
Ce = (sp.factorial(n))/(2**(math.floor(n/2))*sp.factorial(math.floor(n/2)))
#Ce = np.sqrt(2*np.pi*n)*np.power((math.n/np.exp(1)),n)/(2**(n/2))*(factorial(n/2))
#Ce = np.log10(Ce)
#print(np.log10(Ce))
display(Ce)
# Out:
# 52009019647624639963290526316345975658300899834516432645391277269022223728622694994149719806
# 49051667929057004235189809603801753560778911005469196138649691427956583298109701081207647281
# 95694886919757431892726027993403740043699262817967555190830037257724412323865162793369098491
# 79995088700994195718139767910570607857764622436714416383472761568296505271024084119810728336
# 90249414213043994329445556945044943197146975186887358236898711661096459246104247803895503128
# 71354763054824210983682532782114306275335724418536220478597438917078344538638037473973279526
# 81041237155883573360141017457964422374267834881404481967582495548984452690423201581623528759
# 53169779150889077564138313157816332323434728027239903477262746691275442481869053576702551742
# 75907413899009975982659229653302656466814564154340976675402900395308634174918531128101917592
# 43845008121240776911717767523463066449792268259338824675062444342544730352802562286830935223
# 98671801812201604561704214227660767778247516851660502271551916020362513354719012137789546988
# 35367669961764157186428179816424555696855177709283100630777992029034181912555560550265757516
# 64918433666377732849020193690331275497328011289222350936584046161215810079250077457910001858
# 57983117965095838043157402669696425862048071447289287451007271299181739239469894041337064359
# 80160882255145780695284765021220836275223476081095630739371833316728396830572529383397157780
# 34612221558103862698307230737198700995305099427229113631553387798889941569421836814642796942
# 16233353499154292890898380783069768602948122545384333761353301619709889188152534024706976106
# 21296247665988890037928259038840138657493097151466046551204510041755425361050023126796979848
# 12014810105449032279946430200612657698942343833646561436134411878641020129474002860441031274
# 13826587713350214496662951167602008641883744760793496098615787719736081021167394140709364706
# 26772578772428339530526313157503250838270484436904110055654333931363039953352599115293656795
# 28053665393913605003621773008697672767011330849965781131374307127738676280800741116366469131
# 91528823839432054159990127239523100630352303897264654418316259916379446136785570019753831945
# 56731916476770336254261736437960245519571759915530784070280556741823443276819309347062487880
# 00163235849853137805280533818141381891442008679101902783766630576200509739336188676289486171
# 27800163549824903228748364589516723038948599870101586673312048695230919640541957811759029230
# 12781937846662658634942553917326813326688909398197793141642276825179949986938829091232358423
# 66114338626207674685650269670769906841119770052643531407999420046627397951809327942296735484
# 56652886576419351529497294615436810556233169727073817994079001218837060926564132800938189012
# 61896632717286387556092988554970498477140699373669998110731842138474527000471823438985098027
# 60159297415732967223809684681932055951953734749472178690164487070937973145548190709438208851
# 36122569150576572247936603168826008053070416275231587136328791796544213056572725945520305735
# 14575665422104201643057524606260485483080316736023007199079075554821753825799176916881086320
# 30989971006786802096239234519681546345348718530791872581349579051092231018880192348776662953
# 91733645671186139759583597983166348271363874897871331126470904862536069392688508713899812386
# 70053254413214997473095932626427381306915480217733658044072002815560135694944349547956734199
# 40106521775275712582332144526233065976160616282040188434209778693548554092301479256837378281
# 06694078064279065609959823622697487807270222522569974258728858377670237168638442079281099447
# 10810855999557174231110310761033941788876922387710256138246823826467118226480876799823474077
# 31488485069614748806480708478125158207973793567374067536512520220547834653127427262446797526
# 61457422031860945589401665937988037911968885499391183555036710859206407573033918642681843833
# 79172349320534599854342502006338459771810155305401747433549571744373615403433683906734630595
# 80808921326600835518946594597731161901028565138475845381722249158219085357115187422944569675
# 88187807258042167871387621490281478901551153754617547806472967163622180601374456780949912384
# 69246616996351405623717541923173398347459387814466379817378873952254843998837692986010568900
# 81946759655681814935647636369562805784582340434523898961526760522924285084290966595520848007
# 18130490455894832836799840730808807961429748422894294395536813567020665807870408186465522838
# 18165359116682041386527331298154166639633564035841442750331607316704351989134675471742489832
# 50709949143869865927525760068274089305484895024183997432435617688968258847771665108893907059
# 36918705379521859210171083959756710426683916465949837827715165029420801025193411073041142875
# 80697858929585136006899884171153137153629715748276049604712134046813519430724892544390916004
# 77618362506291071868069315466692372949777343580910211508177923474205695082581769893855415967
# 38341789601410888512857861619497318002515964579672239003113578340212604498611811422341774260
# 83963786880705019992765488069862519492850890699770730088573324738760509549782914272981447622
# 43454512900347928530748260274125979071741757803318006521185650699546999605719082051709200037
# 43675629044411246377170485374652169149769715292199894338499971168065238213609561347697949560
# 04183664052002437122614066413314026054053744982763235967034442513488261925017615491794742679
# 14205761841436874041033659335089656262374971133069053598088205290583776806637445528853067290
# 72029560266349459933958678405867067171043909253470381074489576331242262590047259680082153556
# 53750845932679723695109422562912376776873829185738198089904355809131123829119318026657871247
# 90989079234387271521871356075336498691106992449103362097018135606485235499105080998175855534
# 54324154223576054880845722903494170278778739557545677225103883579154879724809357779514182511
# 14862820928442853895019470860217447036499152456140963323713156164999876089265948406148335737
# 46854672206032718802855670560848758534262975985489749812459420815397740754761276982494580148
# 76340585357964560202094036793656109770019117631677744673844623902170917286377756383127278534
# 24532823339497050297973530220098367739832975602348069804183680806513061198424969617616963973
# 35290392962458961153558580078069497195783416281851752290280338366039148184528074709464036309
# 92587127587171290046806832994838662468273155376698162860191621821001525815004889328282087706
# 71283008520412632860369223006413554310914170622888036854264714379872402004499580764816813815
# 10758258196690724374064677958811643721271576173630106313393241159846642613480530849118115906
# 13319504479620917545959456654003298024310314297647388402279633857467028446961824047522766078
# 75774665087771003690867454279750937742023121702944830213641882289362542050535217032069773647
# 20231194750621431645418189020321988115838166612057461594501909842612464314887299088334805921
# 36211510898472578206715492496045654376513328415871837325926198193669242100824270090050695262
# 77086610970977421750592733971082614856100220922740907602929235684141881298347659138839411485
# 42586597362874272169466422061837560030015083995543462792225349078386550291965280487583439411
# 34306869446320572934127795420096129630611040469817241966150145491212716668152076891448993246
# 19734761801998177432861603875884171493038807568378353729691878917435002145232140490452011107
# 9835806714835226876168686009627162292190405423752963542938232421875

# %% [markdown]
# $\color{blue}{\rule{20 cm}{0.1 cm}}$

# %% [markdown]
# ## Case 2

# %% [markdown]
# , calculation of the number of possible different states of the interactome for n different proteins with m different interfaces each

# %% [markdown]
# At the first approximation, this problem is very similar to the previous one, but the number of entities that can interact which each other is $n \times m$, because each interface can interact with each other (e.g. between two proteins having 10 interfaces each, there are as many as 100 possible complexes that are different in a molecular snese). We may then simply take the formula (1) derived under Case 1, and replace n with $n \times m$:

# %%
from sympy import init_printing
init_printing() 
Cd = (sp.factorial(n*m))/((2**((n*m)/2))*(sp.factorial((n*m)/2)))
display(Cd)
#Eq(S('x'),y+z)
# Out:
#  -2250⋅m
# 2       ⋅(4500⋅m)!
# ──────────────────
#     (2250⋅m)!

# %%
#print('Datatype:', np.dtype(Ce))
display(np.longdouble(Ce))

# %%
Cl = 0
for i in range(1, 4501):
    #print(np.log10(i))
    Cl += np.log10(i)
    
display(Cl)

# %% [markdown]
# $\color{blue}{\rule{20 cm}{0.1 cm}}$

# %%
n = 7

# f = factorial(n)
#
# print(f'math factorial')
# print(f)
#
# f = 1
# for i in range(n,1,-1):
#     f=f*i
#
# print(f'loop factorial')
# print(f)

#n = np.linspace(0, 200, 10, dtype = int )
n =4500
#n = list(range(1, 1000,10))
k = 3000
m = 3540
Ca = (n*(n-1))/2
Cb = ((n-2)*(n-3))/2
Cc = (factorial(n))/(pow(2,(n/2)))
Cd = (factorial(n/2))
Ce = (factorial(n))/(pow(2,(n/2))*factorial(n/2))
Cf = (factorial(n*k*m))/((pow(k,(n*k*m)))*(pow(2,((n*k*m)/2)))*factorial((n*k*m)/2))

print()

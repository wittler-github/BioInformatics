# %%
# Python3 program for calculating
# factorial of a number using
# Stirling Approximation
import math
 
# Function for calculating factorial
def stirlingFactorial(n):
    if (n == 1):
        return 1
     
    # value of natural e
    e = 2.71
     
    # evaluating factorial using
    # stirling approximation
    # z = (math.sqrt(2 * 3.14 * n) * math.pow((n / e), n))
    power = (n / e) ** n
    z = (math.sqrt(2 * 3.14 * n) * (power))
    return math.floor(z)
 
# Driver Code
print(stirlingFactorial(1000))
#print(stirlingFactorial(2000))
#print(stirlingFactorial(3000))
print(stirlingFactorial(4))
print(stirlingFactorial(5))
print(stirlingFactorial(6))
print(stirlingFactorial(7))
 
# This code is contributed by mits
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Input In [17], in <cell line: 22>()
#      19     return math.floor(z)
#      21 # Driver Code
# ---> 22 print(stirlingFactorial(1000))
#      23 #print(stirlingFactorial(2000))
#      24 #print(stirlingFactorial(3000))
#      25 print(stirlingFactorial(4))
#
# Input In [17], in stirlingFactorial(n)
#      12 e = 2.71
#      14 # evaluating factorial using
#      15 # stirling approximation
#      16 # z = (math.sqrt(2 * 3.14 * n) * math.pow((n / e), n))
# ---> 17 power = (n / e) ** n
#      18 z = (math.sqrt(2 * 3.14 * n) * (power))
#      19 return math.floor(z)
#
# OverflowError: (34, 'Numerical result out of range')

# %%
e = math.floor(100001.4) ** math.floor(100001.4)
print(e)
# Out:
# ...

# %%
import sympy as sp
from sympy import Sum, factorial
sp.factorial(4500)
# Out:
# ...
